# %%
# imports
import requests
import pandas as pd
import numpy as np

# %%
# gets data from API
def fetchData(url):
    r = requests.get(url)
    return r.json()

# %%
# calls fetchData function for chosen URL
general_info_json = fetchData('https://fantasy.premierleague.com/api/bootstrap-static/')
fixtures_json = fetchData('https://fantasy.premierleague.com/api/fixtures/')
#players_detailed_json = fetchData('https://fantasy.premierleague.com/api/element-summary/{' + element_id + '}/')
#gameweek_live_json = fetchData('https://fantasy.premierleague.com/api/event/{' + event_id + '}/live/')

# %%
# gets a list of keys of the json
general_info_json.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
fixtures_json[0].keys()
# Out:
# dict_keys(['code', 'event', 'finished', 'finished_provisional', 'id', 'kickoff_time', 'minutes', 'provisional_start_time', 'started', 'team_a', 'team_a_score', 'team_h', 'team_h_score', 'stats', 'team_h_difficulty', 'team_a_difficulty', 'pulse_id'])

# %%
#creates data frame
txt = 'elements'
elements_df = pd.DataFrame(general_info_json[txt])

# %%
elements_df.columns
# Out:
# Index(['chance_of_playing_next_round', 'chance_of_playing_this_round', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam',
#        'news', 'news_added', 'now_cost', 'photo', 'points_per_game',
#        'second_name', 'selected_by_percent', 'special', 'squad_number',
#        'status', 'team', 'team_code', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'minutes', 'goals_scored',
#        'assists', 'clean_sheets', 'goals_conceded', 'own_goals',
#        'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
#        'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat',
#        'ict_index', 'influence_rank', 'influence_rank_type', 'creativity_rank',
#        'creativity_rank_type', 'threat_rank', 'threat_rank_type',
#        'ict_index_rank', 'ict_index_rank_type',
#        'corners_and_indirect_freekicks_order',
#        'corners_and_indirect_freekicks_text', 'direct_freekicks_order',
#        'direct_freekicks_text', 'penalties_order', 'penalties_text'],
#       dtype='object')

# %%
fantasy_stats_df = elements_df[['first_name', 'second_name','team','element_type','selected_by_percent','now_cost','transfers_in','transfers_out','value_season', 'total_points']]

# %%
fantasy_stats_df.sort_values(by=['total_points','value_season'], ascending = False)
# Out:
#             first_name second_name  team  element_type selected_by_percent  \
# 328            Mohamed       Salah    11             3                60.8
# 563            Michail     Antonio    19             4                45.6
# 261              Jamie       Vardy     9             4                13.9
# 354  João Pedro Cavaco     Cancelo    12             2                17.4
# 569               Saïd    Benrahma    19             3                37.1
# ..                 ...         ...   ...           ...                 ...
# 608               Luke      Cundle    20             3                 0.1
# 609               Chem    Campbell    20             3                 0.3
# 610          Christian     Marques    20             2                 0.3
# 612              Louie     Moulden    20             1                 0.1
# 10                Sead   Kolasinac     1             2                 0.1
#
#      now_cost  transfers_in  transfers_out value_season  total_points
# 328       127       1470042         729308          5.5            70
# 563        80       3877523        2290663          6.1            49
# 261       104        745517         927875          4.6            48
# 354        62       1076925         316406          7.1            44
# 569        66       3249945        1017664          6.7            44
# ..        ...           ...            ...          ...           ...
# 608        45          8714           5948          0.0             0
# 609        45         33487          21500          0.0             0
# 610        40         24271          22604          0.0             0
# 612        40          4235            588          0.0             0
# 10         43          2524           7808         -0.2            -1
#
# [613 rows x 10 columns]

# %%
fantasy_stats_df.head(30)
# Out:
#          first_name       second_name  team  element_type selected_by_percent  \
# 0             Bernd              Leno     1             1                 1.2
# 1        Rúnar Alex         Rúnarsson     1             1                 0.9
# 2           Willian   Borges Da Silva     1             3                 0.1
# 3    Pierre-Emerick        Aubameyang     1             4                 2.2
# 4            Cédric            Soares     1             2                 0.2
# 5         Alexandre         Lacazette     1             4                 1.0
# 6            Granit             Xhaka     1             3                 0.4
# 7             Pablo              Marí     1             2                 0.1
# 8            Héctor          Bellerín     1             2                 0.3
# 9             Calum          Chambers     1             2                 0.2
# 10             Sead         Kolasinac     1             2                 0.1
# 11    Mohamed Naser   El Sayed Elneny     1             3                 0.4
# 12          Ainsley    Maitland-Niles     1             3                 0.1
# 13              Rob           Holding     1             2                 0.7
# 14           Thomas            Partey     1             3                 0.2
# 15           Kieran           Tierney     1             2                 6.9
# 16          Nicolas              Pépé     1             3                 1.1
# 17            Lucas          Torreira     1             3                 0.2
# 18           Edward           Nketiah     1             4                 0.1
# 19            Emile        Smith Rowe     1             3                 5.5
# 20           Bukayo              Saka     1             3                11.2
# 21          Gabriel         Magalhães     1             2                 0.6
# 22     Konstantinos        Mavropanos     1             2                 0.0
# 23           Mattéo         Guendouzi     1             3                 0.0
# 24  Gabriel Teodoro  Martinelli Silva     1             3                 0.2
# 25          William            Saliba     1             2                 0.0
# 26              Ben             White     1             2                12.3
# 27             Nuno    Varela Tavares     1             2                 0.2
# 28           Albert     Sambi Lokonga     1             3                 0.2
# 29          Folarin           Balogun     1             4                 0.4
#
#     now_cost  transfers_in  transfers_out value_season  total_points
# 0         48         53059         142144          0.8             4
# 1         40         19017          51790          0.0             0
# 2         63           914          19591          0.0             0
# 3         99        213636         263608          2.2            22
# 4         43          9595          18199          0.2             1
# 5         83         21366         145246          0.2             2
# 6         49         16371          70962          0.8             4
# 7         43          4650          10881          0.2             1
# 8         48          3737          66181          0.0             0
# 9         43          7558          23933          0.2             1
# 10        43          2524           7808         -0.2            -1
# 11        45         16279          44494          0.2             1
# 12        53          1618           5112          1.3             7
# 13        43         19148         123076          0.0             0
# 14        50         15900           9651          1.4             7
# 15        49        347674         404356          4.7            23
# 16        71         74888         257927          2.0            14
# 17        45          6292          29745          0.0             0
# 18        54          6024           8818          0.0             0
# 19        53        378649         471886          4.7            25
# 20        63        607831         829186          4.6            29
# 21        50         51140          16782          4.6            23
# 22        45             0             42          0.0             0
# 23        45             0            110          0.0             0
# 24        52          8632          27224          0.8             4
# 25        45             0            163          0.0             0
# 26        44        371130        1150655          5.0            22
# 27        43          7551          19348          0.7             3
# 28        49         11549          17892          2.0            10
# 29        49         42750          50080          0.4             2

# %%
#fantasy_stats_df.replace({'element_type' : { 1 : 'GK', 2 : 'DEF', 3 : 'MID' , 4 : 'FOR'}})

# %%
player_cost_df = elements_df[['id','second_name','cost_change_event','cost_change_event_fall','cost_change_start','now_cost']]

# %%
player_cost_df.head(10)
# Out:
#    id      second_name  cost_change_event  cost_change_event_fall  \
# 0   1             Leno                  0                       0
# 1   2        Rúnarsson                  0                       0
# 2   3  Borges Da Silva                  0                       0
# 3   4       Aubameyang                  0                       0
# 4   5           Soares                  0                       0
# 5   6        Lacazette                  0                       0
# 6   7            Xhaka                  0                       0
# 7   8             Marí                  0                       0
# 8   9         Bellerín                  0                       0
# 9  10         Chambers                  0                       0
#
#    cost_change_start  now_cost
# 0                 -2        48
# 1                  0        40
# 2                 -2        63
# 3                 -1        99
# 4                 -2        43
# 5                 -2        83
# 6                 -1        49
# 7                 -2        43
# 8                 -2        48
# 9                 -2        43

# %%
chance_of_playing_df = elements_df[['id','second_name','chance_of_playing_next_round','chance_of_playing_this_round']]
